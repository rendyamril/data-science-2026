# %% [markdown]
# <a href="https://colab.research.google.com/github/rendyamril/data-science-2026/blob/main/Pertemuan1_MohammadRendyAmril_240401010288.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Nama : Mohammad Rendy Amril
# * NIM : 240401010288
# * Kelas : IF 403
# * Prodi : S1 PJJ Informatika

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana

print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama = "Mahasiswa Informatika" # String
angkatan = 2024 # Integer
ipk = 3.89 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")

# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")

# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Mohammad Rendy Amril", "Informatika", 2026)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Mahasiswa Informatika
# Angkatan: 2024
# IPK : 3.89
# Aktif : True
#
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub
# Hai! Saya Mohammad Rendy Amril dari Informatika, angkatan 2026.

# %% [markdown]
# Dalam modul pembelajaran ini saya mempelajari definisi, konteks dan relevansi Data Science. Serta menggunakan tools modern yang bisa digunakan dalam data science seperti Phyton sebagai bahasa utama, Google Colab, Jupyter Notebook, dan Github
# <br><br>
# **Temuan utamaya** adalah bagaimana Phyton adalah bahasa yang paling umum digunakan dalam data science dan kemudahan penggunaannya
# <br><br>
# **Pertanyaan yang muncul** adalah bagaimana contoh nyata penerapan algoritma spesifik pada tahapan pemodelan data untuk menyelesaikan masalah bisnis yang jauh lebih kompleks di industri?
